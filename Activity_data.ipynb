# %% [markdown]
# # Activity Data

# %%
import pandas as pd
from pandas import json_normalize
import requests
import os

from dotenv import load_dotenv
load_dotenv()


from openapi_client import Configuration, ApiClient
from openapi_client.api.files_api import FilesApi
from openapi_client.api.spreadsheets_api import SpreadsheetsApi


import time  # Import time for managing token expiration


# Initialize global variables for token and expiration
bearer_token = None
token_expiration = 0

# %%
def get_access_token():
    global bearer_token, token_expiration
    
    # Check if the token is expired
    if bearer_token is None or time.time() >= token_expiration:
        host = 'api.eu.wdesk.com'
        path = '/iam/v1/oauth2/token'
        bearer_url = f'https://{host}{path}'
        bearer_headers = {
            'Content-Type': 'application/x-www-form-urlencoded',
            'charset': 'UTF-8'
        }
        bearer_data = {
            'client_id': os.getenv("WORKIVA_CLIENT_ID"),
            'client_secret': os.getenv("WORKIVA_CLIENT_SECRET"),
            'grant_type': 'client_credentials'
        }

        # Requesting the access token
        bearer_result = requests.post(bearer_url, data=bearer_data, headers=bearer_headers)

        # Print status code and response content for debugging
        print("Token Request Status Code:", bearer_result.status_code)
        bearer_json = bearer_result.json()
        print("Token Request Response JSON:", bearer_json)

        # Check if access token is present
        bearer_token = bearer_json.get('access_token')
        
        # Set token expiration to 1 hour from now (3600 seconds)
        token_expiration = time.time() + 3600

    return bearer_token


# Create a configuration object
config = Configuration(
    host="https://api.eu.wdesk.com/platform/v1",
    refresh_token_callback=get_access_token
)

# Create an API client with the bearer token
config.access_token = get_access_token()


# Create an API client
api_client = ApiClient(configuration=config)

# Create an instance of the FilesApi
spreadsheets_api = SpreadsheetsApi(api_client)

# Example: Create a new file


# Call the get_files method
response = spreadsheets_api.get_spreadsheets()


# Display the response
print(response)
# Out:
# Token Request Status Code: 200
# Token Request Response JSON: {'token_type': 'Bearer', 'expires_in': 600, 'access_token': 'eyJraWQiOiJUMEYxZEdneU1GUnZhMlZ1UzJWNVVHRnlaVzUwSGs5QmRYUm9NakJVYjJ0bGJrdGxlVWxFSGs5QmRYUm9NakJVYjJ0bGJrdGxlUjgxTmpJNU5EazVOVE0wTWpFek1USXciLCJhbGciOiJSUzUxMiJ9.....Z1ctLSMagfvmHmJrRQYPmOx1Y2g9QZiB4ZcceFpoLFeK5-RYLVVvWdqBeyeSdSlO9WZ3jI-caT6Ks2GGZ9HRYytpkGtD4rP23yFHnb4M16XjN3OQ7pqo8y-upAc7VHLRh0Y1Izn3evZktHxFKs5zst8FgiqNsN-LvYyg0bRiI8MTMH6HCFsQZ6zW_VAhd6Qa5IRVAPEkDrhiOkwmq36kGmrmdhlYrhNjgIC0velGbtn8X92MN9kMqv_5zdWyRs1S0pjSh1GyPw2dicd9WTym_sVxxBzbctcYzDguOByEhTcA1j-N2yRAYNbCSTMrM_fXTNoXCxPjCGQQaMQFJjhRFA', 'scope': 'task:write dataentity|r file:read graph:write file:write graph_api|w scim|r sox|admin data_tables|w audit_api|r activity:read data_tables|r audit_api|w graph_api|r graph:read task:read'}
# data=[Spreadsheet(id='9aad509d8441489b9b95e6cc79cc0f61', name='Fund Code Fund Name Mapping File', template=False, created=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 13, 9, 34, tzinfo=TzInfo(UTC))), modified=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 13, 9, 34, tzinfo=TzInfo(UTC))), sheets=None), Spreadsheet(id='5628febf9c064c9ea89cd3f56e2c3ab3', name='Spreadsheet_1000_30.06.2024', template=False, created=Action(user=None, date_time=datetime.datetime(2024, 9, 22, 21, 2, 15, tzinfo=TzInfo(UTC))), modified=Action(user=None, date_time=datetime.datetime(2024, 9, 22, 21, 19, 12, tzinfo=TzInfo(UTC))), sheets=None), Spreadsheet(id='062c8fa241f6449988b7cccac3b8d0da', name='Spreadsheet_1415_31.03.2024', template=False, created=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 11, 13, 23, tzinfo=TzInfo(UTC))), modified=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 12, 52, 6, tzinfo=TzInfo(UTC))), sheets=None), Spreadsheet(id='d1c8c90cabd540c3a0272c84b44ae142', name='Spreadsheet_1415_31.03.2024 (1)', template=False, created=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 10, 24, 4, tzinfo=TzInfo(UTC))), modified=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 10, 24, 4, tzinfo=TzInfo(UTC))), sheets=None), Spreadsheet(id='3043049e7a0d4f50a1a169345482313c', name='Spreadsheet_1800_30.06.2024', template=False, created=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 9, 59, 52, tzinfo=TzInfo(UTC))), modified=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 9, 59, 52, tzinfo=TzInfo(UTC))), sheets=None), Spreadsheet(id='13c18d7039fe4d3bbd6cc462635ee4e9', name='Spreadsheet_2100_30.06.2024', template=False, created=Action(user=None, date_time=datetime.datetime(2024, 9, 23, 16, 39, 38, tzinfo=TzInfo(UTC))), modified=Action(user=None, date_time=datetime.datetime(2024, 9, 23, 16, 49, 14, tzinfo=TzInfo(UTC))), sheets=None), Spreadsheet(id='69aaaa3ac0a44da5ad40062f4c02db5d', name='Spreadsheet_2200_30.06.2024', template=False, created=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 10, 17, 5, tzinfo=TzInfo(UTC))), modified=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 10, 17, 5, tzinfo=TzInfo(UTC))), sheets=None), Spreadsheet(id='e0bd5db0332b4308b8c00ff70c95b042', name='Spreadsheet_2700_30.06.2024', template=False, created=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 13, 5, 6, tzinfo=TzInfo(UTC))), modified=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 13, 5, 6, tzinfo=TzInfo(UTC))), sheets=None), Spreadsheet(id='701a618099c5455880be7729f61572f8', name='Spreadsheet_2700_31.03.2024', template=False, created=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 11, 1, 50, tzinfo=TzInfo(UTC))), modified=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 11, 22, 36, tzinfo=TzInfo(UTC))), sheets=None), Spreadsheet(id='38cd6377499d4aeda4129cd5f21a93de', name='Spreadsheet_2700_31.07.2024', template=False, created=Action(user=None, date_time=datetime.datetime(2024, 9, 10, 8, 19, 51, tzinfo=TzInfo(UTC))), modified=Action(user=None, date_time=datetime.datetime(2024, 9, 10, 8, 41, 52, tzinfo=TzInfo(UTC))), sheets=None), Spreadsheet(id='88862d8c8bcd4ed7b47bce4731581353', name='Spreadsheet_2800_30.06.2024', template=False, created=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 10, 27, 25, tzinfo=TzInfo(UTC))), modified=Action(user=None, date_time=datetime.datetime(2024, 8, 29, 10, 27, 25, tzinfo=TzInfo(UTC))), sheets=None), Spreadsheet(id='d489f5e3a7c54b769489055286380202', name='Spreadsheet_2900_30.06.2024', template=False, created=Action(user=None, date_time=datetime.datetime(2024, 10, 2, 14, 14, 50, tzinfo=TzInfo(UTC))), modified=Action(user=None, date_time=datetime.datetime(2024, 10, 2, 14, 14, 50, tzinfo=TzInfo(UTC))), sheets=None), Spreadsheet(id='c6c73f425b6441fdae82a96422d96780', name='Spreadsheet_3100_30.06.2024', template=False, created=Action(user=None, date_time=datetime.datetime(2024, ...

# %%
import pandas as pd

# Function to extract keys and values from a list of File objects
def extract_keys_values(data):
    return [extract_keys_values(item) for item in data] if isinstance(data, list) else data.__dict__

# Convert response data to a pandas DataFrame
extracted_data = extract_keys_values(response.data)
df = pd.json_normalize(extracted_data)

# Display the DataFrame
df
# Out:
#                                   id                                     name  \
# 0   9aad509d8441489b9b95e6cc79cc0f61         Fund Code Fund Name Mapping File
# 1   5628febf9c064c9ea89cd3f56e2c3ab3              Spreadsheet_1000_30.06.2024
# 2   062c8fa241f6449988b7cccac3b8d0da              Spreadsheet_1415_31.03.2024
# 3   d1c8c90cabd540c3a0272c84b44ae142          Spreadsheet_1415_31.03.2024 (1)
# 4   3043049e7a0d4f50a1a169345482313c              Spreadsheet_1800_30.06.2024
# 5   13c18d7039fe4d3bbd6cc462635ee4e9              Spreadsheet_2100_30.06.2024
# 6   69aaaa3ac0a44da5ad40062f4c02db5d              Spreadsheet_2200_30.06.2024
# 7   e0bd5db0332b4308b8c00ff70c95b042              Spreadsheet_2700_30.06.2024
# 8   701a618099c5455880be7729f61572f8              Spreadsheet_2700_31.03.2024
# 9   38cd6377499d4aeda4129cd5f21a93de              Spreadsheet_2700_31.07.2024
# 10  88862d8c8bcd4ed7b47bce4731581353              Spreadsheet_2800_30.06.2024
# 11  d489f5e3a7c54b769489055286380202              Spreadsheet_2900_30.06.2024
# 12  c6c73f425b6441fdae82a96422d96780              Spreadsheet_3100_30.06.2024
# 13  8e0ff0e6a00b4eb58941fd3b4318dd78              Spreadsheet_3100_30.09.2024
# 14  13d83c2328e542d4aee1d6ed67f4a707              Spreadsheet_3100_31.03.2024
# 15  8f27786bf70d448090c913d9d4e643ff              Spreadsheet_3200_30.06.2024
# 16  181c06873a544e028bca6556052e1977              Spreadsheet_3300_30.06.2024
# 17  f60c3cb8eeab47bea641a789067edc4a              Spreadsheet_3400_30.06.2024
# 18  fde27e84e35f4ff5abbda86128e6b2d0              Spreadsheet_3500_30.06.2024
# 19  400dd081aaab428980eafe0782429a11              Spreadsheet_370A_30.06.2024
# 20  1e9bd781c025469aa2132a3ced9047ce              Spreadsheet_380A_30.06.2024
# 21  8c010569274b434f8f8300b48307a67b              Spreadsheet_3900_30.06.2024
# 22  6a32de7e588f4bcc99aa7c50ec1b1964              Spreadsheet_4010_30.06.2024
# 23  42fcd4953dc14f39a20521cc039e0e8e          Spreadsheet_4100_31.03.2024 (1)
# 24  9c2823ad05fd4419a9407cd790106c5c              Spreadsheet_4200_30.06.2024
# 25  b4dcaa30bcd44138bcf961baeae59aca              Spreadsheet_4350_30.06.2024
# 26  7446892d22cb4c3cbabe8e9bc924eb2d              Spreadsheet_4600_30.06.2024
# 27  3a6cc292b21144ca93355f9f759ada24              Spreadsheet_6000_30.06.2024
# 28  505756aa0a9841578a7802f9043dbcf1      Workiva_Spreadsheet_1000_30.06.2024
# 29  806dbcadee3142f98136fe0c621efe07      Workiva_Spreadsheet_1415_31.03.2024
# 30  1afee19b42cb4187b0e0737b1687e281  Workiva_Spreadsheet_1415_31.03.2024 (1)
# 31  7d6aad05cece403aafea4a8360b45b39      Workiva_Spreadsheet_1800_30.06.2024
# 32  3e051b351b2d4fd399b3c2d65f2d9ef4      Workiva_Spreadsheet_2100_30.06.2024
# 33  d9c97cb4b28146f98f0a5b5b8cc4897e      Workiva_Spreadsheet_2200_30.06.2024
# 34  607932bb40544904b49bcef7c67a980e      Workiva_Spreadsheet_2700_30.06.2024
# 35  6eae13131de9450cb6c41b17549cd92d      Workiva_Spreadsheet_2700_31.03.2024
# 36  7e3f092cc0c045aa9602954120a8e6b2      Workiva_Spreadsheet_2700_31.07.2024
# 37  7234ebb4dae4461781091164fc010aee      Workiva_Spreadsheet_2800_30.06.2024
# 38  9affd91e08fa444e8951134e97882146      Workiva_Spreadsheet_2900_30.06.2024
# 39  5fca1567b55946bcaf8718b47843ddde      Workiva_Spreadsheet_3100_30.06.2024
# 40  62ca483748a349d5a3aab79906e2b9b3      Workiva_Spreadsheet_3100_30.09.2024
# 41  6a678c5f18874749ad4fa1ebecbdc4b7      Workiva_Spreadsheet_3100_31.03.2024
# 42  edf707c41bf2442e9618a0cefc43b733      Workiva_Spreadsheet_3200_30.06.2024
# 43  1ee39a358a3947e5a3295b849d08a7a3      Workiva_Spreadsheet_3300_30.06.2024
# 44  20c8cf806002481789c92dcea91c2210      Workiva_Spreadsheet_3400_30.06.2024
# 45  7377751a9d5f49bd9e64f98bd87eebeb      Workiva_Spreadsheet_3500_30.06.2024
# 46  6262a390535e4aebba89b0737717f3cd      Workiva_Spreadsheet_370A_30.06.2024
# 47  748cd24a3eb84e67a67b3eb62f237add      Workiva_Spreadsheet_380A_30.06.2024
# 48  173175df79d24d8ba05d32e4db6d47d6      Workiva_Spreadsheet_3900_30.06.2024
# 49  5bb4ff615ecd44c59aded71cddd638fe      Workiva_Spreadsheet_4010_30.06.2024
# 50  8760d7346ee145398ada623fba8cbf10  Workiva_Spreadsheet_4100_31.03.2024 (1)
# 51  cedd86d7e73e422280459f0a33a2203e      Workiva_Spreadsheet_4200_30.06.2024
# 52  1db33761127f457aae96ccceabfe2615      Workiva_Spreadsheet_4350_30.06.2024
# 53  e56b7cb83e4745e6948cffe558f4b1a8      Workiva_Spreadsheet_4600_30.06.2024
# 54  bccdc93bea804ddd9b195a20fa3a44f6      Workiva_Spreadsheet_6000_30.06.2024
#
#     template                                            created  \
# 0      False  user=None date_time=datetime.datetime(2024, 8,...
# 1      False  user=None date_time=datetime.datetime(2024, 9,...
# 2      False  user=None date_time=datetime.datetime(2024, 8,...
# 3      False  user=None date_time=datetime.datetime(2024, 8,...
# 4      False  user=None date_time=datetime.datetime(2024, 8,...
# 5      False  user=None date_time=datetime.datetime(2024, 9,...
# 6      False  user=None date_time=datetime.datetime(2024, 8,...
# 7      False  user=None date_time=datetime.datetime(2024, 8,...
# 8      False  user=None date_time=datetime.datetime(2024, 8,...
# 9      False  user=None date_time=datetime.datetime(2024, 9,...
# 10     False  user=None date_time=datetime.datetime(2024, 8,...
# 11     False  user=None date_time=datetime.datetime(2024, 10...
# 12     False  user=None date_time=datetime.datetime(2024, 9,...
# 13     False  user=None date_time=datetime.datetime(2024, 9,...
# 14     False  user=None date_time=datetime.datetime(2024, 8,...
# 15     False  user=None date_time=datetime.datetime(2024, 9,...
# 16     False  user=None date_time=datetime.datetime(2024, 8,...
# 17     False  user=None date_time=datetime.datetime(2024, 9,...
# 18     False  user=None date_time=datetime.datetime(2024, 8,...
# 19     False  user=None date_time=datetime.datetime(2024, 8,...
# 20     False  user=None date_time=datetime.datetime(2024, 8,...
# 21     False  user=None date_time=datetime.datetime(2024, 8,...
# 22     False  user=None date_time=datetime.datetime(2024, 8,...
# 23     False  user=None date_time=datetime.datetime(2024, 8,...
# 24     False  user=None date_time=datetime.datetime(2024, 8,...
# 25     False  user=None date_time=datetime.datetime(2024, 8,...
# 26     False  user=None date_time=datetime.datetime(2024, 9,...
# 27     False  user=None date_time=datetime.datetime(2024, 8,...
# 28     False  user=None date_time=datetime.datetime(2024, 9,...
# 29     False  user=None date_time=datetime.datetime(2024, 8,...
# 30     False  user=None date_time=datetime.datetime(2024, 8,...
# 31     False  user=None date_time=datetime.datetime(2024, 8,...
# 32     False  user=None date_time=datetime.datetime(2024, 9,...
# 33     False  user=None date_time=datetime.datetime(2024, 8,...
# 34     False  user=None date_time=datetime.datetime(2024, 8,...
# 35     False  user=None date_time=datetime.datetime(2024, 8,...
# 36     False  user=None date_time=datetime.datetime(2024, 9,...
# 37     False  user=None date_time=datetime.datetime(2024, 8,...
# 38     False  user=None date_time=datetime.datetime(2024, 10...
# 39     False  user=None date_time=datetime.datetime(2024, 9,...
# 40     False  user=None date_time=datetime.datetime(2024, 9,...
# 41     False  user=None date_time=datetime.datetime(2024, 8,...
# 42     False  user=None date_time=datetime.datetime(2024, 9,...
# 43     False  user=None date_time=datetime.datetime(2024, 8,...
# 44     False  user=None date_time=datetime.datetime(2024, 9,...
# 45     False  user=None date_time=datetime.datetime(2024, 8,...
# 46     False  user=None date_time=datetime.datetime(2024, 8,...
# 47     False  user=None date_time=datetime.datetime(2024, 8,...
# 48     False  user=None date_time=datetime.datetime(2024, 8,...
# 49     False  user=None date_time=datetime.datetime(2024, 8,...
# 50     False  user=None date_time=datetime.datetime(2024, 8,...
# 51     False  user=None date_time=datetime.datetime(2024, 8,...
# 52     False  user=None date_time=datetime.datetime(2024, 8,...
# 53     False  user=None date_time=datetime.datetime(2024, 9,...
# 54     False  user=None date_time=datetime.datetime(2024, 8,...
#
#                                              modified sheets
# 0   user=None date_time=datetime.datetime(2024, 8,...   None
# 1   user=None date_time=datetime.datetime(2024, 9,...   None
# 2   user=None date_time=datetime.datetime(2024, 8,...   None
# 3   user=None date_time=datetime.datetime(2024, 8,...   None
# 4   user=None date_time=datetime.datetime(2024, 8,...   None
# 5   user=None date_time=datetime.datetime(2024, 9,...   None
# 6   user=None date_time=datetime.datetime(2024, 8,...   None
# 7   user=None date_time=datetime.datetime(2024, 8,...   None
# 8   user=None date_time=datetime.datetime(2024, 8,...   None
# 9   user=None date_time=datetime.datetime(2024, 9,...   None
# 10  user=None date_time=datetime.datetime(2024, 8,...   None
# 11  user=None date_time=datetime.datetime(2024, 10...   None
# 12  user=None date_time=datetime.datetime(2024, 9,...   None
# 13  user=None date_time=datetime.datetime(2024, 9,...   None
# 14  user=None date_time=datetime.datetime(2024, 8,...   None
# 15  user=None date_time=datetime.datetime(2024, 9,...   None
# 16  user=None date_time=datetime.datetime(2024, 8,...   None
# 17  user=None date_time=datetime.datetime(2024, 9,...   None
# 18  user=None date_time=datetime.datetime(2024, 8,...   None
# 19  user=None date_time=datetime.datetime(2024, 8,...   None
# 20  user=None date_time=datetime.datetime(2024, 8,...   None
# 21  user=None date_time=datetime.datetime(2024, 8,...   None
# 22  user=None date_time=datetime.datetime(2024, 8,...   None
# 23  user=None date_time=datetime.datetime(2024, 8,...   None
# 24  user=None date_time=datetime.datetime(2024, 8,...   None
# 25  user=None date_time=datetime.datetime(2024, 8,...   None
# 26  user=None date_time=datetime.datetime(2024, 9,...   None
# 27  user=None date_time=datetime.datetime(2024, 8,...   None
# 28  user=None date_time=datetime.datetime(2024, 9,...   None
# 29  user=None date_time=datetime.datetime(2024, 8,...   None
# 30  user=None date_time=datetime.datetime(2024, 8,...   None
# 31  user=None date_time=datetime.datetime(2024, 8,...   None
# 32  user=None date_time=datetime.datetime(2024, 9,...   None
# 33  user=None date_time=datetime.datetime(2024, 8,...   None
# 34  user=None date_time=datetime.datetime(2024, 10...   None
# 35  user=None date_time=datetime.datetime(2024, 8,...   None
# 36  user=None date_time=datetime.datetime(2024, 9,...   None
# 37  user=None date_time=datetime.datetime(2024, 8,...   None
# 38  user=None date_time=datetime.datetime(2024, 10...   None
# 39  user=None date_time=datetime.datetime(2024, 9,...   None
# 40  user=None date_time=datetime.datetime(2024, 9,...   None
# 41  user=None date_time=datetime.datetime(2024, 8,...   None
# 42  user=None date_time=datetime.datetime(2024, 9,...   None
# 43  user=None date_time=datetime.datetime(2024, 8,...   None
# 44  user=None date_time=datetime.datetime(2024, 9,...   None
# 45  user=None date_time=datetime.datetime(2024, 8,...   None
# 46  user=None date_time=datetime.datetime(2024, 8,...   None
# 47  user=None date_time=datetime.datetime(2024, 8,...   None
# 48  user=None date_time=datetime.datetime(2024, 8,...   None
# 49  user=None date_time=datetime.datetime(2024, 8,...   None
# 50  user=None date_time=datetime.datetime(2024, 8,...   None
# 51  user=None date_time=datetime.datetime(2024, 8,...   None
# 52  user=None date_time=datetime.datetime(2024, 8,...   None
# 53  user=None date_time=datetime.datetime(2024, 9,...   None
# 54  user=None date_time=datetime.datetime(2024, 8,...   None

# %%
# Filter the DataFrame to get only the rows where the 'name' column starts with 'Spreadsheet_'
filtered_spreadsheets_df = df[df['name'].str.startswith('Workiva_Spreadsheet_')]

# Display the filtered DataFrame
filtered_spreadsheets_df
# Out:
#                                   id                                     name  \
# 28  505756aa0a9841578a7802f9043dbcf1      Workiva_Spreadsheet_1000_30.06.2024
# 29  806dbcadee3142f98136fe0c621efe07      Workiva_Spreadsheet_1415_31.03.2024
# 30  1afee19b42cb4187b0e0737b1687e281  Workiva_Spreadsheet_1415_31.03.2024 (1)
# 31  7d6aad05cece403aafea4a8360b45b39      Workiva_Spreadsheet_1800_30.06.2024
# 32  3e051b351b2d4fd399b3c2d65f2d9ef4      Workiva_Spreadsheet_2100_30.06.2024
# 33  d9c97cb4b28146f98f0a5b5b8cc4897e      Workiva_Spreadsheet_2200_30.06.2024
# 34  607932bb40544904b49bcef7c67a980e      Workiva_Spreadsheet_2700_30.06.2024
# 35  6eae13131de9450cb6c41b17549cd92d      Workiva_Spreadsheet_2700_31.03.2024
# 36  7e3f092cc0c045aa9602954120a8e6b2      Workiva_Spreadsheet_2700_31.07.2024
# 37  7234ebb4dae4461781091164fc010aee      Workiva_Spreadsheet_2800_30.06.2024
# 38  9affd91e08fa444e8951134e97882146      Workiva_Spreadsheet_2900_30.06.2024
# 39  5fca1567b55946bcaf8718b47843ddde      Workiva_Spreadsheet_3100_30.06.2024
# 40  62ca483748a349d5a3aab79906e2b9b3      Workiva_Spreadsheet_3100_30.09.2024
# 41  6a678c5f18874749ad4fa1ebecbdc4b7      Workiva_Spreadsheet_3100_31.03.2024
# 42  edf707c41bf2442e9618a0cefc43b733      Workiva_Spreadsheet_3200_30.06.2024
# 43  1ee39a358a3947e5a3295b849d08a7a3      Workiva_Spreadsheet_3300_30.06.2024
# 44  20c8cf806002481789c92dcea91c2210      Workiva_Spreadsheet_3400_30.06.2024
# 45  7377751a9d5f49bd9e64f98bd87eebeb      Workiva_Spreadsheet_3500_30.06.2024
# 46  6262a390535e4aebba89b0737717f3cd      Workiva_Spreadsheet_370A_30.06.2024
# 47  748cd24a3eb84e67a67b3eb62f237add      Workiva_Spreadsheet_380A_30.06.2024
# 48  173175df79d24d8ba05d32e4db6d47d6      Workiva_Spreadsheet_3900_30.06.2024
# 49  5bb4ff615ecd44c59aded71cddd638fe      Workiva_Spreadsheet_4010_30.06.2024
# 50  8760d7346ee145398ada623fba8cbf10  Workiva_Spreadsheet_4100_31.03.2024 (1)
# 51  cedd86d7e73e422280459f0a33a2203e      Workiva_Spreadsheet_4200_30.06.2024
# 52  1db33761127f457aae96ccceabfe2615      Workiva_Spreadsheet_4350_30.06.2024
# 53  e56b7cb83e4745e6948cffe558f4b1a8      Workiva_Spreadsheet_4600_30.06.2024
# 54  bccdc93bea804ddd9b195a20fa3a44f6      Workiva_Spreadsheet_6000_30.06.2024
#
#     template                                            created  \
# 28     False  user=None date_time=datetime.datetime(2024, 9,...
# 29     False  user=None date_time=datetime.datetime(2024, 8,...
# 30     False  user=None date_time=datetime.datetime(2024, 8,...
# 31     False  user=None date_time=datetime.datetime(2024, 8,...
# 32     False  user=None date_time=datetime.datetime(2024, 9,...
# 33     False  user=None date_time=datetime.datetime(2024, 8,...
# 34     False  user=None date_time=datetime.datetime(2024, 8,...
# 35     False  user=None date_time=datetime.datetime(2024, 8,...
# 36     False  user=None date_time=datetime.datetime(2024, 9,...
# 37     False  user=None date_time=datetime.datetime(2024, 8,...
# 38     False  user=None date_time=datetime.datetime(2024, 10...
# 39     False  user=None date_time=datetime.datetime(2024, 9,...
# 40     False  user=None date_time=datetime.datetime(2024, 9,...
# 41     False  user=None date_time=datetime.datetime(2024, 8,...
# 42     False  user=None date_time=datetime.datetime(2024, 9,...
# 43     False  user=None date_time=datetime.datetime(2024, 8,...
# 44     False  user=None date_time=datetime.datetime(2024, 9,...
# 45     False  user=None date_time=datetime.datetime(2024, 8,...
# 46     False  user=None date_time=datetime.datetime(2024, 8,...
# 47     False  user=None date_time=datetime.datetime(2024, 8,...
# 48     False  user=None date_time=datetime.datetime(2024, 8,...
# 49     False  user=None date_time=datetime.datetime(2024, 8,...
# 50     False  user=None date_time=datetime.datetime(2024, 8,...
# 51     False  user=None date_time=datetime.datetime(2024, 8,...
# 52     False  user=None date_time=datetime.datetime(2024, 8,...
# 53     False  user=None date_time=datetime.datetime(2024, 9,...
# 54     False  user=None date_time=datetime.datetime(2024, 8,...
#
#                                              modified sheets
# 28  user=None date_time=datetime.datetime(2024, 9,...   None
# 29  user=None date_time=datetime.datetime(2024, 8,...   None
# 30  user=None date_time=datetime.datetime(2024, 8,...   None
# 31  user=None date_time=datetime.datetime(2024, 8,...   None
# 32  user=None date_time=datetime.datetime(2024, 9,...   None
# 33  user=None date_time=datetime.datetime(2024, 8,...   None
# 34  user=None date_time=datetime.datetime(2024, 10...   None
# 35  user=None date_time=datetime.datetime(2024, 8,...   None
# 36  user=None date_time=datetime.datetime(2024, 9,...   None
# 37  user=None date_time=datetime.datetime(2024, 8,...   None
# 38  user=None date_time=datetime.datetime(2024, 10...   None
# 39  user=None date_time=datetime.datetime(2024, 9,...   None
# 40  user=None date_time=datetime.datetime(2024, 9,...   None
# 41  user=None date_time=datetime.datetime(2024, 8,...   None
# 42  user=None date_time=datetime.datetime(2024, 9,...   None
# 43  user=None date_time=datetime.datetime(2024, 8,...   None
# 44  user=None date_time=datetime.datetime(2024, 9,...   None
# 45  user=None date_time=datetime.datetime(2024, 8,...   None
# 46  user=None date_time=datetime.datetime(2024, 8,...   None
# 47  user=None date_time=datetime.datetime(2024, 8,...   None
# 48  user=None date_time=datetime.datetime(2024, 8,...   None
# 49  user=None date_time=datetime.datetime(2024, 8,...   None
# 50  user=None date_time=datetime.datetime(2024, 8,...   None
# 51  user=None date_time=datetime.datetime(2024, 8,...   None
# 52  user=None date_time=datetime.datetime(2024, 8,...   None
# 53  user=None date_time=datetime.datetime(2024, 9,...   None
# 54  user=None date_time=datetime.datetime(2024, 8,...   None

# %%
# Initialize a list to hold DataFrames for each spreadsheet
dataframes = []

# Loop over the filtered spreadsheet IDs
for spreadsheet_id in filtered_spreadsheets_df['id']:
    # Retrieve the spreadsheet data
    spreadsheet_data = spreadsheets_api.get_sheets(spreadsheet_id)
    extracted_data = extract_keys_values(spreadsheet_data.data)
    spreadsheet_data = pd.json_normalize(extracted_data)  
    # print(spreadsheet_data.head())
    asset_sheet = spreadsheet_data[spreadsheet_data['name'] == "Portfolio Overview"]
    print(asset_sheet)

    # Define the path to save the file
    save_path = os.path.join(f'sheet_data_{spreadsheet_id}.txt')

    # Save the sheet details to the specified path
    with open(save_path, 'w') as file:
        file.write(asset_sheet.to_string())

    for sheet_id in asset_sheet['id']:
        sheet_details = spreadsheets_api.get_sheet_data(spreadsheet_id, sheet_id)
        # print(sheet_details)
        with open(f'sheet_data_{sheet_id}.txt', 'w') as file:
            file.write(sheet_details.to_str())
        # break
        # Convert the retrieved sheet data to a pandas DataFrame
        sheet_df = pd.json_normalize(sheet_details)
        # Append the DataFrame to the list
        dataframes.append(sheet_df)

    break
    

# # Optionally, concatenate all DataFrames into a single DataFrame
# all_spreadsheets_df = pd.concat(dataframes, ignore_index=True)

# # Display the combined DataFrame
# all_spreadsheets_df
# Out:
#                                   id                name  \
# 43  21ffc7681e784a7eaefa67b1fcb6e0e6  Portfolio Overview
#
#                                                parent  index  \
# 43  id='f81b8923cd35437b920584878812a18c' name='Da...      4
#
#                                              children dataset
# 43  [id='62e2f51a68504331bf33cfe9f099617d' name='P...    None
